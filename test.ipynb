# %%
from data import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from data import *
#
# File /export/ssule25/hyperparameters-bilevel-optimization/data.py:5
#       1 """Data generation helpers for biexponential recovery experiments."""
#       3 from __future__ import annotations
# ----> 5 import numpy as np
#       6 import torch
#       9 def biexponential(t: torch.Tensor, c: torch.Tensor, lam: torch.Tensor) -> torch.Tensor:
#
# ModuleNotFoundError: No module named 'numpy'
